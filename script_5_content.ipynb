# %%
import DataCleaning_meta
import DataCleaning_reviews_5
import DataCleaning_reviews
import numpy as np
import pandas as pd
import pickle
# Out:
# [nltk_data] Downloading package stopwords to /home/nico/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/nico/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/nico/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/nico/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/nico/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/nico/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/nico/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/nico/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
user_input = str(input('what is the userText'))
# import meta data and then filter them
df_start_meta = DataCleaning_meta.data_clean_meta("../meta_Grocery_and_Gourmet_Food.json.gz")
# filter the lifestyle sections I want
df_lifestyle_meta = DataCleaning_meta.lifestylefilter(df_start_meta)
df_lifestyle_meta.to_json('df_lifestyle_meta.json')
# bring in the reviews and process all the text for vecorizer
# Out:
# what is the userText Without a doubt, pizza is the greatest food that has ever been developed. It has all the major food groups, an nice mix of carbohydrates, protein, calcium, and can be loaded down the vegetables. Some people don't like the gluten in the crust, so a gluten-free option is like hitting the trifecta.
# 287051  total length of list of products
# ...

# %%
df_lifestyle_meta2 = pd.read_json('./df_lifestyle_meta.json')

# %%
df_lifestyle_meta2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98075 entries, 1 to 287050
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   description          98075 non-null  object
#  1   brand                98075 non-null  object
#  2   rank                 98075 non-null  object
#  3   price                98075 non-null  object
#  4   asin                 98075 non-null  object
#  5   name                 98075 non-null  object
#  6   features             98075 non-null  object
#  7   categories           98075 non-null  object
#  8   main_category        98075 non-null  object
#  9   all_text             98075 non-null  object
#  10  lifestyle_processed  98075 non-null  object
# dtypes: object(11)
# memory usage: 9.0+ MB

# %%
df_start_reviews = DataCleaning_reviews_5.data_clean('../reviews_Grocery_and_Gourmet_Food_5.json.gz')
df_processed_reviews = DataCleaning_reviews_5.all_text_processing(df_start_reviews)
df_processed_reviews.to_json('df_processed_reviews_5.json')
# Out:
# {'reviewerID': 'A1VEELTKS8NLZB', 'asin': '616719923X', 'reviewerName': 'Amazon Customer', 'helpful': [0, 0], 'reviewText': 'Just another flavor of Kit Kat but the taste is unique and a bit different.  The only thing that is bothersome is the price.  I thought it was a bit expensive....', 'overall': 4.0, 'summary': 'Good Taste', 'unixReviewTime': 1370044800, 'reviewTime': '06 1, 2013'}
# Done with loading review5 datadata
# Done with processing review data

# %%
df_processed_reviews2 = pd.read_json("../df_processed_reviews_5.json")

# %%
df_lifestyle_meta2 = pd.read_json('../df_lifestyle_meta.json')

# %%
df_processed_reviews2.head()
# Out:
#        reviewerID        asin     reviewerName  \
# 0  A1VEELTKS8NLZB  616719923X  Amazon Customer
# 1  A14R9XMZVJ6INB  616719923X          amf0001
# 2  A27IQHDZFQFNGG  616719923X          Caitlin
# 3  A31QY5TASILE89  616719923X     DebraDownSth
# 4  A2LWK003FFMCI5  616719923X         Diana X.
#
#                                           reviewText helpful_votes  rating  \
# 0  Just another flavor of Kit Kat but the taste i...        [0, 0]       4
# 1  I bought this on impulse and it comes from Jap...        [0, 1]       3
# 2  Really good. Great gift for any fan of green t...        [3, 4]       4
# 3  I had never had it before, was curious to see ...        [0, 0]       5
# 4  I've been looking forward to trying these afte...        [1, 2]       4
#
#                                          reviewTitle  \
# 0                                         Good Taste
# 1  3.5 stars,  sadly not as wonderful as I had hoped
# 2                                               Yum!
# ...

# %%
m = df_processed_reviews2['asin'].isin(df_lifestyle_meta2['asin'])
df_filtred = df_processed_reviews2[m]

# %%
df_filtred
# Out:
#             reviewerID        asin  \
# 47      A3EBHHCZO6V2A4  B00005344V
# 48      A1P9UMP1XSE6MI  B00005344V
# 49      A2F488C4PLWGEI  B00005344V
# 50       AO1HXV7DWZZIR  B00005344V
# 51      A1WSALRW89YKFA  B00005344V
# ...                ...         ...
# 151249  A2L6QS8SVHT9RG  B00KCJRVO2
# 151250   AFJFXN42RZ3G2  B00KCJRVO2
# 151251   ASEBX8TBYWQWA  B00KCJRVO2
# 151252   ANKQGTXHREOI5  B00KCJRVO2
# 151253  A2CF66KIQ3RKX3  B00KCJRVO2
#
#                                             reviewerName  \
# 47                                  Amaranth "music fan"
# 48                                       Amazon Customer
# 49                                            Gandalphar
# 50                         Larry Jaques "an avid reader"
# 51                                             Liz Jolie
# ...                                                  ...
# 151249              randomartco "period film aficionado"
# 151250                               R. DelParto "Rose2"
# ...
